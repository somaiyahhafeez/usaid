# %%
import pandas as pd

df = pd.read_csv("ukraine_military_aid.csv")
df
# Out:
#       Country ID Country Code Country Name  Region ID         Region Name  \
# 0            804          UKR      Ukraine          2  Europe and Eurasia
# 1            804          UKR      Ukraine          2  Europe and Eurasia
# 2            804          UKR      Ukraine          2  Europe and Eurasia
# 3            804          UKR      Ukraine          2  Europe and Eurasia
# 4            804          UKR      Ukraine          2  Europe and Eurasia
# ...          ...          ...          ...        ...                 ...
# 1808         804          UKR      Ukraine          2  Europe and Eurasia
# 1809         804          UKR      Ukraine          2  Europe and Eurasia
# 1810         804          UKR      Ukraine          2  Europe and Eurasia
# 1811         804          UKR      Ukraine          2  Europe and Eurasia
# 1812         804          UKR      Ukraine          2  Europe and Eurasia
#
#       Income Group ID            Income Group Name Income Group Acronym  \
# ...

# %%
columns_to_drop = [
    'Transaction Type Name',
    'Funding Agency Acronym',
    'Managing Sub-agency or Bureau ID',
    'Implementing Partner Sub-category ID',
    'Activity End Date',
    'Income Group ID',
    'International Purpose Code',
    'Foreign Assistance Objective ID',
    'US Sector ID',
    'Implementing Partner Category ID',
    'Activity ID',
    'Managing Agency Acronym',
    'US Category ID',
    'Managing Sub-agency or Bureau Acronym',
    'International Category ID',
    'Funding Agency ID',
    'Aid Type Group ID',
    'Managing Agency ID',
    'Submission ID',
    'Country ID',
    'International Sector Code',
    'Transaction Type ID',
    'Region ID',
    'Implementing Partner ID',
    'Activity Start Date',
    'Income Group Acronym', 'Current Dollar Amount', 'Activity Project Number', 'Funding Agency Name', 'Implementing Partner Sub-category Name', 'Managing Agency Name'
]

df = df.drop(columns=columns_to_drop)

df
# Out:
#      Country Code Country Name         Region Name  \
# 0             UKR      Ukraine  Europe and Eurasia
# 1             UKR      Ukraine  Europe and Eurasia
# 2             UKR      Ukraine  Europe and Eurasia
# 3             UKR      Ukraine  Europe and Eurasia
# 4             UKR      Ukraine  Europe and Eurasia
# ...           ...          ...                 ...
# 1808          UKR      Ukraine  Europe and Eurasia
# 1809          UKR      Ukraine  Europe and Eurasia
# 1810          UKR      Ukraine  Europe and Eurasia
# 1811          UKR      Ukraine  Europe and Eurasia
# 1812          UKR      Ukraine  Europe and Eurasia
#
#                 Income Group Name   Managing Sub-agency or Bureau Name  \
# 0     Lower Middle Income Country           Political-Military Affairs
# 1     Lower Middle Income Country  Defense Security Cooperation Agency
# 2     Lower Middle Income Country  Defense Security Cooperation Agency
# ...

# %%
df_filtered = df[df['Fiscal Year'] > 2014]
df_filtered
# Out:
#      Country Code Country Name         Region Name  \
# 0             UKR      Ukraine  Europe and Eurasia
# 1             UKR      Ukraine  Europe and Eurasia
# 2             UKR      Ukraine  Europe and Eurasia
# 3             UKR      Ukraine  Europe and Eurasia
# 4             UKR      Ukraine  Europe and Eurasia
# ...           ...          ...                 ...
# 1729          UKR      Ukraine  Europe and Eurasia
# 1730          UKR      Ukraine  Europe and Eurasia
# 1731          UKR      Ukraine  Europe and Eurasia
# 1732          UKR      Ukraine  Europe and Eurasia
# 1733          UKR      Ukraine  Europe and Eurasia
#
#                 Income Group Name   Managing Sub-agency or Bureau Name  \
# 0     Lower Middle Income Country           Political-Military Affairs
# 1     Lower Middle Income Country  Defense Security Cooperation Agency
# 2     Lower Middle Income Country  Defense Security Cooperation Agency
# ...

# %%
ukraine_military = df_filtered.groupby('Fiscal Year')['Constant Dollar Amount'].sum()
ukraine_military
# Out:
# Fiscal Year
# 2015      96054988
# 2016     388412663
# 2017     314867228
# 2018     361713171
# 2019     349975271
# 2020     328709623
# 2021     199252734
# 2022    7745410039
# 2023     262489957
# Name: Constant Dollar Amount, dtype: int64

# %%
before_invasion =  96054988 + 388412663 + 314867228 + 361713171 + 349975271+ 328709623+ 199252734

before_invasion
# Out:
# 2038985678

# %%
after_invasion = 7745410039 + 262489957

after_invasion
# Out:
# 8007899996
